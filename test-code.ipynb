# %%
sample_pose = {'frame': 101, 'keypoints': {'NOSE': {'pose_name': 'NOSE', 'x': 0.7443973422050476, 'y': -0.13674987852573395, 'z': -1.4234802722930908, 'visibility': 0.981597900390625}, 'LEFT_EYE_INNER': {'pose_name': 'LEFT_EYE_INNER', 'x': 0.7682081460952759, 'y': -0.21715766191482544, 'z': -1.3647955656051636, 'visibility': 0.9600402116775513}, 'LEFT_EYE': {'pose_name': 'LEFT_EYE', 'x': 0.7876946330070496, 'y': -0.20596107840538025, 'z': -1.3643767833709717, 'visibility': 0.9613584280014038}, 'LEFT_EYE_OUTER': {'pose_name': 'LEFT_EYE_OUTER', 'x': 0.8058379888534546, 'y': -0.19329656660556793, 'z': -1.3642619848251343, 'visibility': 0.9585995674133301}, 'RIGHT_EYE_INNER': {'pose_name': 'RIGHT_EYE_INNER', 'x': 0.703680157661438, 'y': -0.24084928631782532, 'z': -1.4099156856536865, 'visibility': 0.9661402106285095}, 'RIGHT_EYE': {'pose_name': 'RIGHT_EYE', 'x': 0.6779181957244873, 'y': -0.24735718965530396, 'z': -1.4100233316421509, 'visibility': 0.9694042801856995}, 'RIGHT_EYE_OUTER': {'pose_name': 'RIGHT_EYE_OUTER', 'x': 0.651889979839325, 'y': -0.25328174233436584, 'z': -1.4105280637741089, 'visibility': 0.9689444303512573}, 'LEFT_EAR': {'pose_name': 'LEFT_EAR', 'x': 0.7944453954696655, 'y': -0.13808506727218628, 'z': -0.9955592155456543, 'visibility': 0.9557473063468933}, 'RIGHT_EAR': {'pose_name': 'RIGHT_EAR', 'x': 0.5593125224113464, 'y': -0.2116229087114334, 'z': -1.1848728656768799, 'visibility': 0.9681926965713501}, 'MOUTH_LEFT': {'pose_name': 'MOUTH_LEFT', 'x': 0.7512763738632202, 'y': -0.02150089107453823, 'z': -1.2827715873718262, 'visibility': 0.9936850070953369}, 'MOUTH_RIGHT': {'pose_name': 'MOUTH_RIGHT', 'x': 0.6877522468566895, 'y': -0.04514816775918007, 'z': -1.3374892473220825, 'visibility': 0.9944825768470764}, 'LEFT_SHOULDER': {'pose_name': 'LEFT_SHOULDER', 'x': 0.8238503336906433, 'y': 0.31346553564071655, 'z': -0.628616213798523, 'visibility': 0.998153567314148}, 'RIGHT_SHOULDER': {'pose_name': 'RIGHT_SHOULDER', 'x': 0.27744534611701965, 'y': 0.16339616477489471, 'z': -1.042122721672058, 'visibility': 0.9992096424102783}, 'LEFT_ELBOW': {'pose_name': 'LEFT_ELBOW', 'x': 0.8708598017692566, 'y': 0.7952491044998169, 'z': -0.20910148322582245, 'visibility': 0.9071391224861145}, 'RIGHT_ELBOW': {'pose_name': 'RIGHT_ELBOW', 'x': 0.10292311012744904, 'y': 0.6629709005355835, 'z': -0.9216300249099731, 'visibility': 0.9348510503768921}, 'LEFT_WRIST': {'pose_name': 'LEFT_WRIST', 'x': 0.9819613695144653, 'y': 1.2461440563201904, 'z': -0.36032429337501526, 'visibility': 0.5664380788803101}, 'RIGHT_WRIST': {'pose_name': 'RIGHT_WRIST', 'x': 0.10976384580135345, 'y': 1.1309666633605957, 'z': -1.1693919897079468, 'visibility': 0.6407771706581116}, 'LEFT_PINKY': {'pose_name': 'LEFT_PINKY', 'x': 1.0422712564468384, 'y': 1.3555632829666138, 'z': -0.4395548403263092, 'visibility': 0.4587974548339844}, 'RIGHT_PINKY': {'pose_name': 'RIGHT_PINKY', 'x': 0.09475746005773544, 'y': 1.3031209707260132, 'z': -1.282089114189148, 'visibility': 0.518509030342102}, 'LEFT_INDEX': {'pose_name': 'LEFT_INDEX', 'x': 1.0218913555145264, 'y': 1.3730735778808594, 'z': -0.548303484916687, 'visibility': 0.4891958236694336}, 'RIGHT_INDEX': {'pose_name': 'RIGHT_INDEX', 'x': 0.1592017412185669, 'y': 1.2821803092956543, 'z': -1.3882912397384644, 'visibility': 0.5495820641517639}, 'LEFT_THUMB': {'pose_name': 'LEFT_THUMB', 'x': 0.9695645570755005, 'y': 1.3352062702178955, 'z': -0.4174167215824127, 'visibility': 0.5220366716384888}, 'RIGHT_THUMB': {'pose_name': 'RIGHT_THUMB', 'x': 0.1761905550956726, 'y': 1.230037808418274, 'z': -1.2157511711120605, 
'visibility': 0.5630092024803162}, 'LEFT_HIP': {'pose_name': 'LEFT_HIP', 'x': 0.5378187894821167, 'y': 1.0285533666610718, 'z': 0.06211085245013237, 'visibility': 0.7237574458122253}, 'RIGHT_HIP': {'pose_name': 'RIGHT_HIP', 'x': 0.26207712292671204, 'y': 1.0054558515548706, 'z': -0.0611799955368042, 'visibility': 0.7280493974685669}, 'LEFT_KNEE': {'pose_name': 'LEFT_KNEE', 'x': 0.4868224561214447, 'y': 1.8565949201583862, 'z': 0.4881881773471832, 'visibility': 0.17709453403949738}, 'RIGHT_KNEE': {'pose_name': 'RIGHT_KNEE', 'x': 0.17834700644016266, 'y': 1.8310163021087646, 'z': 0.23672597110271454, 'visibility': 0.14633890986442566}, 'LEFT_ANKLE': {'pose_name': 'LEFT_ANKLE', 'x': 0.39832931756973267, 'y': 2.4974374771118164, 'z': 1.5639941692352295, 'visibility': 0.02987823076546192}, 'RIGHT_ANKLE': {'pose_name': 'RIGHT_ANKLE', 'x': 0.10088974237442017, 'y': 2.436354160308838, 'z': 1.148106336593628, 'visibility': 0.03103349357843399}, 'LEFT_HEEL': {'pose_name': 'LEFT_HEEL', 'x': 0.3646879494190216, 'y': 
2.611672878265381, 'z': 1.6463924646377563, 'visibility': 0.024532867595553398}, 'RIGHT_HEEL': {'pose_name': 'RIGHT_HEEL', 'x': 0.06399759650230408, 'y': 2.5355887413024902, 'z': 1.2184944152832031, 'visibility': 0.04656263068318367}, 'LEFT_FOOT_INDEX': {'pose_name': 'LEFT_FOOT_INDEX', 'x': 0.42291754484176636, 'y': 2.713799476623535, 'z': 1.1788160800933838, 'visibility': 0.016077272593975067}, 'RIGHT_FOOT_INDEX': {'pose_name': 'RIGHT_FOOT_INDEX', 'x': 0.17995324730873108, 'y': 2.671478748321533, 'z': 0.5611074566841125, 'visibility': 0.022824926301836967}}}

# %%
label_names = sample_pose['keypoints'].keys()
label_names
# Out:
# dict_keys(['NOSE', 'LEFT_EYE_INNER', 'LEFT_EYE', 'LEFT_EYE_OUTER', 'RIGHT_EYE_INNER', 'RIGHT_EYE', 'RIGHT_EYE_OUTER', 'LEFT_EAR', 'RIGHT_EAR', 'MOUTH_LEFT', 'MOUTH_RIGHT', 'LEFT_SHOULDER', 'RIGHT_SHOULDER', 'LEFT_ELBOW', 'RIGHT_ELBOW', 'LEFT_WRIST', 'RIGHT_WRIST', 'LEFT_PINKY', 'RIGHT_PINKY', 'LEFT_INDEX', 'RIGHT_INDEX', 'LEFT_THUMB', 'RIGHT_THUMB', 'LEFT_HIP', 'RIGHT_HIP', 'LEFT_KNEE', 'RIGHT_KNEE', 'LEFT_ANKLE', 'RIGHT_ANKLE', 'LEFT_HEEL', 'RIGHT_HEEL', 'LEFT_FOOT_INDEX', 'RIGHT_FOOT_INDEX'])

# %%
import datetime
sample_pose = {'WRIST': [0.2684667706489563, 0.6736271977424622, -1.5099010397534585e-07, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'THUMB_CMC': [0.3100096583366394, 0.6707863211631775, -0.015525593422353268, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'THUMB_MCP': [0.3446710705757141, 0.7037428617477417, -0.024334240704774857, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'THUMB_IP': [0.3636831045150757, 0.7470444440841675, -0.027967462316155434, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'THUMB_TIP': [0.37310320138931274, 0.7816606163978577, -0.029388293623924255, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'INDEX_FINGER_MCP': [0.30877014994621277, 0.7262219786643982, -0.04345988482236862, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'INDEX_FINGER_PIP': [0.34499573707580566, 0.7866171002388, -0.051684021949768066, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'INDEX_FINGER_DIP': [0.3647518455982208, 0.7937792539596558, -0.047394417226314545, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'INDEX_FINGER_TIP': [0.36977869272232056, 0.7850695848464966, -0.04187018796801567, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'MIDDLE_FINGER_MCP': [0.2887055575847626, 0.7489079833030701, -0.03792788088321686, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'MIDDLE_FINGER_PIP': [0.32755225896835327, 0.8138788342475891, -0.046965036541223526, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'MIDDLE_FINGER_DIP': [0.3493976891040802, 0.8135903477668762, -0.04176634922623634, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'MIDDLE_FINGER_TIP': [0.355476975440979, 0.7963472604751587, -0.0362355075776577, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'RING_FINGER_MCP': [0.275626003742218, 0.766849935054779, -0.031339697539806366, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'RING_FINGER_PIP': [0.3150101900100708, 0.8230745792388916, -0.03854377195239067, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'RING_FINGER_DIP': [0.33514565229415894, 0.818103551864624, -0.03321550786495209, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'RING_FINGER_TIP': [0.3397192656993866, 0.8010647296905518, -0.02812148816883564, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'PINKY_MCP': [0.26912280917167664, 0.7798628211021423, -0.025108996778726578, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'PINKY_PIP': [0.30079638957977295, 0.8211925625801086, -0.03248157724738121, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'PINKY_DIP': [0.3186929523944855, 0.8176597356796265, -0.030817914754152298, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)], 'PINKY_TIP': [0.32398173213005066, 0.8036686778068542, -0.027750134468078613, 0.0, datetime.datetime(2025, 11, 15, 17, 17, 50, 816175)]}

# %%
label_names = ['R_' + k for k in sample_pose.keys()]
print(label_names)
# Out:
# ['R_WRIST', 'R_THUMB_CMC', 'R_THUMB_MCP', 'R_THUMB_IP', 'R_THUMB_TIP', 'R_INDEX_FINGER_MCP', 'R_INDEX_FINGER_PIP', 'R_INDEX_FINGER_DIP', 'R_INDEX_FINGER_TIP', 'R_MIDDLE_FINGER_MCP', 'R_MIDDLE_FINGER_PIP', 'R_MIDDLE_FINGER_DIP', 'R_MIDDLE_FINGER_TIP', 'R_RING_FINGER_MCP', 'R_RING_FINGER_PIP', 'R_RING_FINGER_DIP', 'R_RING_FINGER_TIP', 'R_PINKY_MCP', 'R_PINKY_PIP', 'R_PINKY_DIP', 'R_PINKY_TIP']

# %%
label_names = ['L_' + k for k in sample_pose.keys()]
print(label_names)
